# %% [markdown]
# <a href="https://colab.research.google.com/github/Roshan1920/BookHub/blob/main/01_db_connection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install psycopg2-binary sqlalchemy pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 45.6 MB/s eta 0:00:00
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

DB_USER = "neondb_owner"
DB_PASSWORD = "npg_n5YHeBpyJdo9"
DB_HOST = "ep-polished-tree-ahl3jg2g-pooler.c-3.us-east-1.aws.neon.tech"
DB_PORT = "5432"
DB_NAME = "neondb"

engine = create_engine(
    f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

# Test connection
pd.read_sql("SELECT table_name FROM information_schema.tables WHERE table_schema='public'", engine)
# Out:
#          table_name
# 0       commodities
# 1      daily_prices
# 2            mandis
# 3  locality_mapping

# %%
# !git clone https://github.com/Roshan1920/Mandi-price-geo_intelligence.git
# Out:
# Cloning into 'Mandi-price-geo_intelligence'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 11 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), done.

# %%
# %cd Mandi-price-geo_intelligence
# !ls
# Out:
# [Errno 2] No such file or directory: 'Mandi-price-geo_intelligence'
# /content/Mandi-price-geo_intelligence
# data  notebooks  README.md  sql

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !pip install psycopg2-binary sqlalchemy pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 45.6 MB/s eta 0:00:00
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

DB_USER = "neondb_owner"
DB_PASSWORD = "npg_n5YHeBpyJdo9"
DB_HOST = "ep-polished-tree-ahl3jg2g-pooler.c-3.us-east-1.aws.neon.tech"
DB_PORT = "5432"
DB_NAME = "neondb"

engine = create_engine(
    f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

# Test connection
pd.read_sql("SELECT table_name FROM information_schema.tables WHERE table_schema='public'", engine)
# Out:
#          table_name
# 0       commodities
# 1      daily_prices
# 2            mandis
# 3  locality_mapping

# %%
# !git clone https://github.com/Roshan1920/Mandi-price-geo_intelligence.git
# Out:
# Cloning into 'Mandi-price-geo_intelligence'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 11 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), done.

# %%
# %cd Mandi-price-geo_intelligence
# !ls
# Out:
# [Errno 2] No such file or directory: 'Mandi-price-geo_intelligence'
# /content/Mandi-price-geo_intelligence
# data  notebooks  README.md  sql

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !pip install psycopg2-binary sqlalchemy pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 45.6 MB/s eta 0:00:00
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

DB_USER = "neondb_owner"
DB_PASSWORD = "npg_n5YHeBpyJdo9"
DB_HOST = "ep-polished-tree-ahl3jg2g-pooler.c-3.us-east-1.aws.neon.tech"
DB_PORT = "5432"
DB_NAME = "neondb"

engine = create_engine(
    f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

# Test connection
pd.read_sql("SELECT table_name FROM information_schema.tables WHERE table_schema='public'", engine)
# Out:
#          table_name
# 0       commodities
# 1      daily_prices
# 2            mandis
# 3  locality_mapping

# %%
# !git clone https://github.com/Roshan1920/Mandi-price-geo_intelligence.git
# Out:
# Cloning into 'Mandi-price-geo_intelligence'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 11 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), done.

# %%
# %cd Mandi-price-geo_intelligence
# !ls
# Out:
# [Errno 2] No such file or directory: 'Mandi-price-geo_intelligence'
# /content/Mandi-price-geo_intelligence
# data  notebooks  README.md  sql

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
